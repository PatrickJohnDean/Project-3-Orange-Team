# %%
import pandas as pd
import pprint
from pathlib import Path

# %%
csv = pd.read_csv("/Users/chaunguyen/Desktop/NTAD_National_Bridge_Inventory_-6282134062105639862.csv")
philly_df = csv[(csv["STATE_CODE_001"] == 42) & (csv["COUNTY_CODE_003"] == 101)]
philly_df
# Out:
# /var/folders/xb/9yf9xtb12zn2ly4v3jjr252h0000gn/T/ipykernel_72157/74856270.py:1: DtypeWarning: Columns (2,6,8,18,32,37,39,40,72,74,76,97,99,103,108,109) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv = pd.read_csv("/Users/chaunguyen/Desktop/NTAD_National_Bridge_Inventory_-6282134062105639862.csv")
#         OBJECTID  STATE_CODE_001 STRUCTURE_NUMBER_008  RECORD_TYPE_005A  \
# 452996    452997              42                 7193                 1
# 466359    466360              42                38303                 1
# 466360    466361              42                38305                 1
# 466361    466362              42                38310                 1
# 466362    466363              42                38311                 1
# ...          ...             ...                  ...               ...
# 472437    472438              42      000000000057500                 1
# ...

# %%
poor_df = csv[csv["BRIDGE_CONDITION"] == "P"]
poor_df
# Out:
#         OBJECTID  STATE_CODE_001 STRUCTURE_NUMBER_008  RECORD_TYPE_005A  \
# 6              7               1               000002                 1
# 7              8               1               000004                 1
# 9             10               1               000005                 1
# 18            19               1               000024                 1
# 20            21               1               000039                 1
# ...          ...             ...                  ...               ...
# 621571    621572              78              STX6991                 1
# 621572    621573              78              STX7020                 1
# 621573    621574              78              STX7025                 1
# 621574    621575              78            STX702505                 1
# 621575    621576              78              STX7215                 1
#
#         ROUTE_PREFIX_005B  SERVICE_LEVEL_005C ROUTE_NUMBER_005D  \
# ...

# %%
poor_df = poor_df[[ "LATDD", "LONGDD", "BRIDGE_CONDITION"]]
poor_df
# Out:
#             LATDD     LONGDD BRIDGE_CONDITION
# 6       33.908411 -87.288211                P
# 7       33.764153 -87.358486                P
# 9       33.564936 -88.077364                P
# 18      33.439958 -86.699156                P
# 20      32.811647 -85.169233                P
# ...           ...        ...              ...
# 621571  17.724517 -64.803747                P
# 621572  17.719483 -64.803067                P
# 621573  17.723572 -64.789658                P
# 621574  17.716378 -64.883181                P
# 621575  17.739078 -64.798275                P
#
# [42404 rows x 3 columns]

# %%
poor_df.to_csv("Poor Bridges Across USA.csv", index=False)

# %%
philly_df.columns
# Out:
# Index(['OBJECTID', 'STATE_CODE_001', 'STRUCTURE_NUMBER_008',
#        'RECORD_TYPE_005A', 'ROUTE_PREFIX_005B', 'SERVICE_LEVEL_005C',
#        'ROUTE_NUMBER_005D', 'DIRECTION_005E', 'HIGHWAY_DISTRICT_002',
#        'COUNTY_CODE_003',
#        ...
#        'SUBMITTED_BY', 'BRIDGE_CONDITION', 'LOWEST_RATING', 'DECK_AREA',
#        'STATUS', 'DATE', 'LATDD', 'LONGDD', 'x', 'y'],
#       dtype='object', length=130)

# %%
philly_df = philly_df[["LATDD", "LONGDD", "YEAR_BUILT_027", "OWNER_022", "MAINTENANCE_021", "BRIDGE_CONDITION", 
                       "BRIDGE_IMP_COST_094", "ROADWAY_IMP_COST_095", "TOTAL_IMP_COST_096", 
                       "YEAR_RECONSTRUCTED_106", "DECK_WIDTH_MT_052", "STRUCTURE_LEN_MT_049"]]
philly_df
# Out:
#             LATDD     LONGDD  YEAR_BUILT_027  OWNER_022  MAINTENANCE_021  \
# 452996  40.103450 -74.961092            1990          4                4
# 466359  39.989944 -75.250461            1935          1               27
# 466360  40.000700 -75.227539            1910          1                1
# 466361  40.006661 -75.199589            1953          1                1
# 466362  40.007103 -75.192278            1960          1                1
# ...           ...        ...             ...        ...              ...
# 472437  39.971314 -75.123447            2019          1                1
# 472558  39.942597 -75.211397            2020         27               27
# 472680  40.058022 -75.195347            2020          1                1
# 472724  39.998933 -75.086278            2021          1                1
# 472949  39.893306 -75.191028            1941         26               26
#
#        BRIDGE_CONDITION  BRIDGE_IMP_COST_094  ROADWAY_IMP_COST_095  \
# ...

# %%
philly_df.rename(columns={"LATDD": "Latitude",
                          "LONGDD": "Longitude",
                          "YEAR_BUILT_027": "Year Built",
                          "OWNER_022": "Owner",
                          "MAINTENANCE_021": "Maintenance Responsibility",
                          "BRIDGE_CONDITION": "Bridge Condition",
                          "BRIDGE_IMP_COST_094": "Bridge Improvement Cost",
                          "ROADWAY_IMP_COST_095": "Roadway Improvement Cost",
                          "TOTAL_IMP_COST_096": "Total Improvement Cost",
                          "YEAR_RECONSTRUCTED_106": "Year Reconstructed",
                          "DECK_WIDTH_MT_052": "Deck Width",
                          "STRUCTURE_LEN_MT_049": "Structure Length"}, inplace=True)
# Out:
# /var/folders/xb/9yf9xtb12zn2ly4v3jjr252h0000gn/T/ipykernel_37178/3279322391.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   philly_df.rename(columns={"LATDD": "Latitude",

# %%
philly_df.dtypes
# Out:
# Latitude                      float64
# Longitude                     float64
# Year Built                      int64
# Owner                           int64
# Maintenance Responsibility      int64
# Bridge Condition               object
# Bridge Improvement Cost       float64
# Roadway Improvement Cost      float64
# Total Improvement Cost        float64
# Year Reconstructed            float64
# Deck Width                    float64
# Structure Length              float64
# dtype: object

# %%
philly_df.to_csv("Philadelphia Cleaned DOT Data.csv", index=False)
