# %%
import pandas as pd
import folium
from geopy.geocoders import Nominatim

# %%
df = pd.read_csv('C:/Users/samka/upenn/MY_HOMEWORK/Project-3-Orange-Team/NTAD_National_Bridge_Inventory_-6282134062105639862 (2).csv', low_memory=False)
filtered_df = df[(df['STATE_CODE_001'] == 42) & (df['COUNTY_CODE_003'] == 101)]
filtered_df
# Out:
#         OBJECTID  STATE_CODE_001 STRUCTURE_NUMBER_008  RECORD_TYPE_005A  \
# 452996    452997              42      000000000007193                 1
# 466359    466360              42      000000000038303                 1
# 466360    466361              42      000000000038305                 1
# 466361    466362              42      000000000038310                 1
# 466362    466363              42      000000000038311                 1
# ...          ...             ...                  ...               ...
# 472437    472438              42      000000000057500                 1
# 472558    472559              42      000000000057682                 1
# 472680    472681              42      000000000067832                 1
# 472724    472725              42      000000000067987                 1
# 472949    472950              42      000000000069671                 1
#
#         ROUTE_PREFIX_005B  SERVICE_LEVEL_005C ROUTE_NUMBER_005D  \
# ...

# %%
filtered_df = filtered_df[["LATDD", "LONGDD", "YEAR_BUILT_027", "OWNER_022", "MAINTENANCE_021", "BRIDGE_CONDITION", "BRIDGE_IMP_COST_094", "ROADWAY_IMP_COST_095", "TOTAL_IMP_COST_096", "YEAR_RECONSTRUCTED_106", "DECK_WIDTH_MT_052", "STRUCTURE_LEN_MT_049", "STATE_CODE_001", "COUNTY_CODE_003"]]
filtered_df
# Out:
#             LATDD     LONGDD  YEAR_BUILT_027  OWNER_022  MAINTENANCE_021  \
# 452996  40.103450 -74.961092            1990          4                4
# 466359  39.989944 -75.250461            1935          1               27
# 466360  40.000700 -75.227539            1910          1                1
# 466361  40.006661 -75.199589            1953          1                1
# 466362  40.007103 -75.192278            1960          1                1
# ...           ...        ...             ...        ...              ...
# 472437  39.971314 -75.123447            2019          1                1
# 472558  39.942597 -75.211397            2020         27               27
# 472680  40.058022 -75.195347            2020          1                1
# 472724  39.998933 -75.086278            2021          1                1
# 472949  39.893306 -75.191028            1941         26               26
#
#        BRIDGE_CONDITION  BRIDGE_IMP_COST_094  ROADWAY_IMP_COST_095  \
# ...

# %%
print("Shape Before Deleting Missing Values:", filtered_df.shape)
print("Missing Values Before Deleting:\n" + str(filtered_df.isnull().sum()), "\n")
rows_with_nan = filtered_df[filtered_df.isnull().any(axis=1)]
print("Rows with NaN values:")
print(rows_with_nan)
# Out:
# Shape Before Deleting Missing Values: (593, 14)
# Missing Values Before Deleting:
# LATDD                       0
# LONGDD                      0
# YEAR_BUILT_027              0
# OWNER_022                   0
# MAINTENANCE_021             0
# BRIDGE_CONDITION            0
# BRIDGE_IMP_COST_094        71
# ROADWAY_IMP_COST_095       71
# TOTAL_IMP_COST_096         71
# YEAR_RECONSTRUCTED_106    108
# DECK_WIDTH_MT_052           0
# STRUCTURE_LEN_MT_049        0
# STATE_CODE_001              0
# COUNTY_CODE_003             0
# dtype: int64
#
# Rows with NaN values:
#             LATDD     LONGDD  YEAR_BUILT_027  OWNER_022  MAINTENANCE_021  \
# 466362  40.007103 -75.192278            1960          1                1
# 466363  40.006550 -75.193561            1960          1                1
# 466364  40.016014 -75.175697            1960          1                1
# 466386  40.043556 -75.020661            1697          1                3
# ...

# %%
filtered_df.columns = ["Latitude",
"Longitude",
"Year Built",
"Owner",
"Maintenance",
"Bridge Condition",
"Bridge Improvement Cost",
"Roadway Improvement Cost",
"Total Improvement Cost",
"Year Reconstructed",
"Deck Width",
"Structure Length",
"PA",
"Philadelphia"]

# %%
filtered_df
# Out:
#          Latitude  Longitude  Year Built  Owner  Maintenance Bridge Condition  \
# 452996  40.103450 -74.961092        1990      4            4                G
# 466359  39.989944 -75.250461        1935      1           27                F
# 466360  40.000700 -75.227539        1910      1            1                P
# 466361  40.006661 -75.199589        1953      1            1                F
# 466362  40.007103 -75.192278        1960      1            1                F
# ...           ...        ...         ...    ...          ...              ...
# 472437  39.971314 -75.123447        2019      1            1                G
# 472558  39.942597 -75.211397        2020     27           27                G
# 472680  40.058022 -75.195347        2020      1            1                G
# 472724  39.998933 -75.086278        2021      1            1                G
# 472949  39.893306 -75.191028        1941     26           26                F
#
# ...

# %%
filtered_df = filtered_df[["PA",
"Philadelphia",
"Latitude",
"Longitude",
"Year Built",
"Owner",
"Maintenance",
"Bridge Condition",
"Bridge Improvement Cost",
"Roadway Improvement Cost",
"Total Improvement Cost",
"Year Reconstructed",
"Deck Width",
"Structure Length"]]

# %%
filtered_df
# Out:
#         PA  Philadelphia   Latitude  Longitude  Year Built  Owner  \
# 452996  42           101  40.103450 -74.961092        1990      4
# 466359  42           101  39.989944 -75.250461        1935      1
# 466360  42           101  40.000700 -75.227539        1910      1
# 466361  42           101  40.006661 -75.199589        1953      1
# 466362  42           101  40.007103 -75.192278        1960      1
# ...     ..           ...        ...        ...         ...    ...
# 472437  42           101  39.971314 -75.123447        2019      1
# 472558  42           101  39.942597 -75.211397        2020     27
# 472680  42           101  40.058022 -75.195347        2020      1
# 472724  42           101  39.998933 -75.086278        2021      1
# 472949  42           101  39.893306 -75.191028        1941     26
#
#         Maintenance Bridge Condition  Bridge Improvement Cost  \
# 452996            4                G                      0.0
# ...

# %%
good_bridges_df = filtered_df[filtered_df['Bridge Condition'] == 'G']
good_bridges_df
# Out:
#         PA  Philadelphia   Latitude  Longitude  Year Built  Owner  \
# 452996  42           101  40.103450 -74.961092        1990      4
# 466377  42           101  39.953183 -75.182481        1934      1
# 466389  42           101  39.974800 -75.198806        1890      1
# 466397  42           101  40.062650 -75.085769        1905      1
# 466409  42           101  39.961544 -75.182642        1988      1
# ...     ..           ...        ...        ...         ...    ...
# 472436  42           101  39.972975 -75.120481        2020      1
# 472437  42           101  39.971314 -75.123447        2019      1
# 472558  42           101  39.942597 -75.211397        2020     27
# 472680  42           101  40.058022 -75.195347        2020      1
# 472724  42           101  39.998933 -75.086278        2021      1
#
#         Maintenance Bridge Condition  Bridge Improvement Cost  \
# 452996            4                G                      0.0
# ...

# %%
m = folium.Map([40.10345, -74.961092], zoom_start=11)



# Iterate over the "Good" bridges DataFrame and add markers to the map
for index, row in good_bridges_df.iterrows():
    folium.Marker(
    location=[row['Latitude'], row['Longitude']],
    popup=f"Bridge {index}", 
    icon=folium.Icon(color="green"),
    ).add_to(m)
m

# Show the map in a browser
#m.save("good_bridges_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
fair_bridges_df = filtered_df[filtered_df['Bridge Condition'] == 'F']
fair_bridges_df
# Out:
#         PA  Philadelphia   Latitude  Longitude  Year Built  Owner  \
# 466359  42           101  39.989944 -75.250461        1935      1
# 466361  42           101  40.006661 -75.199589        1953      1
# 466362  42           101  40.007103 -75.192278        1960      1
# 466363  42           101  40.006550 -75.193561        1960      1
# 466364  42           101  40.016014 -75.175697        1960      1
# ...     ..           ...        ...        ...         ...    ...
# 471224  42           101  39.893997 -75.225997        1979     25
# 471228  42           101  39.885897 -75.218697        1980     25
# 471816  42           101  39.956839 -75.147378        1933     32
# 471817  42           101  39.954339 -75.147933        1933     32
# 472949  42           101  39.893306 -75.191028        1941     26
#
#         Maintenance Bridge Condition  Bridge Improvement Cost  \
# 466359           27                F                     86.0
# ...

# %%
m = folium.Map([40.10345, -74.961092], zoom_start=11)



# Iterate over the "Good" bridges DataFrame and add markers to the map
for index, row in fair_bridges_df.iterrows():
    folium.Marker(
    location=[row['Latitude'], row['Longitude']],
    popup=f"Bridge {index}", 
    icon=folium.Icon(color="orange"),
    ).add_to(m)

m    
# Show the map in a browser
#m.save("fair_bridges_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
poor_bridges_df = filtered_df[filtered_df['Bridge Condition'] == 'P']
poor_bridges_df
# Out:
#         PA  Philadelphia   Latitude  Longitude  Year Built  Owner  \
# 466360  42           101  40.000700 -75.227539        1910      1
# 466366  42           101  40.019228 -75.163675        1960      1
# 466368  42           101  40.023742 -75.133300        1955      1
# 466376  42           101  39.954375 -75.179819        1932      1
# 466378  42           101  39.954294 -75.179269        1932      1
# ...     ..           ...        ...        ...         ...    ...
# 466792  42           101  40.015131 -75.150767        1929      4
# 466849  42           101  39.991775 -75.085486        1974      1
# 466866  42           101  40.019444 -75.146111        1961      1
# 467006  42           101  40.012300 -75.147197        1913     27
# 472286  42           101  39.960194 -75.159694        1892      4
#
#         Maintenance Bridge Condition  Bridge Improvement Cost  \
# 466360            1                P                     25.0
# ...

# %%
m = folium.Map([40.10345, -74.961092], zoom_start=11)



# Iterate over the "Good" bridges DataFrame and add markers to the map
for index, row in poor_bridges_df.iterrows():
    folium.Marker(
    location=[row['Latitude'], row['Longitude']],
    popup=f"Bridge {index}", 
    icon=folium.Icon(color="red"),
    ).add_to(m)
m
# Show the map in a browser
#m.save("poor_bridges_map.html")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
geoLoc = Nominatim(user_agent="GetLoc")
locname = geoLoc.reverse("39.963467, -75.186778")
print(locname.address)
# Out:
# Spring Garden Street, Mantua, Philadelphia, Philadelphia County, Pennsylvania, 19104, United States

# %%
geolocator = Nominatim(user_agent="bridge_address")
def reverse_geocode(row):
    location = geolocator.reverse((row["Latitude"], row['Longitude']), exactly_one=True)
    if location:
        return location.address
    else:
        return "N/A"
#Add in Address column with reverse geocode data
filtered_df["Address"] = filtered_df.apply(reverse_geocode, axis=1)
filtered_df
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
# ...
