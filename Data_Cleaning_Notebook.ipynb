# %%
import gdown
from config import file_id
import pandas as pd
import pprint
from pathlib import Path
from geopy.geocoders import Nominatim
import re
import warnings
warnings.filterwarnings("ignore")

# %%
# Set the output name for the National Bridge Inventory csv file to be downloaded from Google Drive
output = 'National_Bridge_Inventory.csv'

#Use gdown to download the Bridge Inventory csv file 
gdown.download(f'https://drive.google.com/uc?id={file_id}', output, quiet=False)

#Read in the Bridge Inventory with Pandas
bridge_csv = pd.read_csv(output)

#Create our initial data frame containing only the bridge data for the bridges maintained by the city of Philadelphia
philly_bridges = bridge_csv[(bridge_csv["STATE_CODE_001"] == 42) & (bridge_csv["COUNTY_CODE_003"] == 101) 
                            & (bridge_csv["MAINTENANCE_021"] == 4)] 

philly_bridges
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Y2oOsuU7MxC9HGaz3bZIrTlK_QCXGsZ8
# From (redirected): https://drive.google.com/uc?id=1Y2oOsuU7MxC9HGaz3bZIrTlK_QCXGsZ8&confirm=t&uuid=f00617aa-e315-4b0d-8a5a-e1baa71ef7fc
# To: /Users/Jake/Documents/GitHub/Project-3-Orange-Team/National_Bridge_Inventory.csv
# 100%|████████████████████████████████████████| 281M/281M [00:03<00:00, 74.9MB/s]
#         OBJECTID  STATE_CODE_001 STRUCTURE_NUMBER_008  RECORD_TYPE_005A  \
# 452996    452997              42                 7193                 1
# 466573    466574              42                38954                 1
# 466579    466580              42                38968                 1
# 466580    466581              42                38970                 1
# 466616    466617              42                39034                 1
# ...          ...             ...                  ...               ...
# 471579    471580              42      000000000054173                 1
# 471995    471996              42      000000000055933                 1
# 471997    471998              42      000000000055937                 1
# 472286    472287              42      000000000057140                 1
# 472287    472288              42      000000000057141                 1
#
#         ROUTE_PREFIX_005B  SERVICE_LEVEL_005C ROUTE_NUMBER_005D  \
# 452996                  3                   1             00000
# 466573                  3                   1             00000
# 466579                  3                   1             00000
# 466580                  3                   1             00000
# 466616                  3                   1             00000
# ...                   ...                 ...               ...
# 471579                  5                   0             00000
# 471995                  5                   0             00000
# 471997                  5                   0             00000
# 472286                  5                   0             00000
# 472287                  5                   6             00000
#
#         DIRECTION_005E HIGHWAY_DISTRICT_002  COUNTY_CODE_003  ...  \
# 452996               0                    6              101  ...
# 466573               0                    6              101  ...
# 466579               0                    6              101  ...
# 466580               0                    6              101  ...
# 466616               0                    6              101  ...
# ...                ...                  ...              ...  ...
# 471579               3                    6              101  ...
# 471995               3                    6              101  ...
# 471997               1                    6              101  ...
# 472286               2                    6              101  ...
# 472287               0                    6              101  ...
#
#         SUBMITTED_BY BRIDGE_CONDITION  LOWEST_RATING DECK_AREA STATUS  DATE  \
# 452996            42                G              7    237.90     AM  1202
# 466573            42                F              6    631.68     AM  1202
# 466579            42                P              4   2688.70     ST   723
# 466580            42                P              4    439.02     ST   723
# 466616            42                F              5   2384.64     ST   723
# ...              ...              ...            ...       ...    ...   ...
# 471579            42                G              7    592.02     ST   723
# 471995            42                G              7    795.60     ST   723
# 471997            42                G              7    838.95     ST   723
# 472286            42                P              3     82.08     ST   723
# 472287            42                G              7    110.04     ST   723
#
#             LATDD     LONGDD          x          y
# 452996  40.103450 -74.961092 -74.961092  40.103450
# 466573  40.017092 -75.211428 -75.211428  40.017092
# 466579  39.963467 -75.186778 -75.186778  39.963467
# 466580  39.963861 -75.185025 -75.185025  39.963861
# 466616  40.035356 -75.208878 -75.208878  40.035356
# ...           ...        ...        ...        ...
# 471579  39.958900 -75.170372 -75.170372  39.958900
# 471995  39.959400 -75.173906 -75.173906  39.959400
# 471997  39.959500 -75.175500 -75.175500  39.959500
# 472286  39.960194 -75.159694 -75.159694  39.960194
# 472287  40.024667 -75.223028 -75.223028  40.024667
#
# [158 rows x 130 columns]

# %%
# # Load in the bridge inventory csv
# bridge_csv = pd.read_csv("/Users/Jake/Downloads/NTAD_National_Bridge_Inventory_-6282134062105639862.csv")

# # Create a data frame with only they bridges maintatined by the city of Philadelphia

# philly_bridges = bridge_csv[(bridge_csv["STATE_CODE_001"] == 42) & (bridge_csv["COUNTY_CODE_003"] == 101) 
#                             & (bridge_csv["MAINTENANCE_021"] == 4)] 

# philly_bridges

# %%
# Edit the columns to only the ones we're concerend with

philly_bridges = philly_bridges[["OBJECTID", "LATDD", "LONGDD", "YEAR_BUILT_027", "BRIDGE_CONDITION", 
                       "ADT_029", "DECK_WIDTH_MT_052", "STRUCTURE_LEN_MT_049"]]

philly_bridges
# Out:
#         OBJECTID      LATDD     LONGDD  YEAR_BUILT_027 BRIDGE_CONDITION  \
# 452996    452997  40.103450 -74.961092            1990                G
# 466573    466574  40.017092 -75.211428            1928                F
# 466579    466580  39.963467 -75.186778            1964                P
# 466580    466581  39.963861 -75.185025            1964                P
# 466616    466617  40.035356 -75.208878            1957                F
# ...          ...        ...        ...             ...              ...
# 471579    471580  39.958900 -75.170372            2017                G
# 471995    471996  39.959400 -75.173906            2018                G
# 471997    471998  39.959500 -75.175500            2018                G
# 472286    472287  39.960194 -75.159694            1892                P
# 472287    472288  40.024667 -75.223028            1998                G
#
#         ADT_029  DECK_WIDTH_MT_052  STRUCTURE_LEN_MT_049
# 452996     9729               13.0                  18.3
# 466573    14596               19.2                  32.9
# 466579    27042               16.1                 167.0
# 466580    27042               16.2                  27.1
# 466616    28301               20.7                 115.2
# ...         ...                ...                   ...
# 471579     8800               19.8                  29.9
# 471995    13020               20.4                  39.0
# 471997    12400               25.5                  32.9
# 472286      150                4.8                  17.1
# 472287       10                8.4                  13.1
#
# [158 rows x 8 columns]

# %%
# Rename the columns to be more user friendly

philly_bridges.rename(columns={"OBJECTID": "Bridge_ID",
                          "LATDD": "Latitude",
                          "LONGDD": "Longitude",
                          "YEAR_BUILT_027": "Year_Built",
                          "BRIDGE_CONDITION": "Bridge_Condition",
                          "ADT_029": "Average_Daily_Traffic",
                          "DECK_WIDTH_MT_052": "Deck_Width",
                          "STRUCTURE_LEN_MT_049": "Structure_Length"}, inplace=True)

philly_bridges
# Out:
#         Bridge_ID   Latitude  Longitude  Year_Built Bridge_Condition  \
# 452996     452997  40.103450 -74.961092        1990                G
# 466573     466574  40.017092 -75.211428        1928                F
# 466579     466580  39.963467 -75.186778        1964                P
# 466580     466581  39.963861 -75.185025        1964                P
# 466616     466617  40.035356 -75.208878        1957                F
# ...           ...        ...        ...         ...              ...
# 471579     471580  39.958900 -75.170372        2017                G
# 471995     471996  39.959400 -75.173906        2018                G
# 471997     471998  39.959500 -75.175500        2018                G
# 472286     472287  39.960194 -75.159694        1892                P
# 472287     472288  40.024667 -75.223028        1998                G
#
#         Average_Daily_Traffic  Deck_Width  Structure_Length
# 452996                   9729        13.0              18.3
# 466573                  14596        19.2              32.9
# 466579                  27042        16.1             167.0
# 466580                  27042        16.2              27.1
# 466616                  28301        20.7             115.2
# ...                       ...         ...               ...
# 471579                   8800        19.8              29.9
# 471995                  13020        20.4              39.0
# 471997                  12400        25.5              32.9
# 472286                    150         4.8              17.1
# 472287                     10         8.4              13.1
#
# [158 rows x 8 columns]

# %%
#Calculate the square footage of each bridge in order to calculate the estimated cost to repair and to replace

philly_bridges.loc[:,"SqFt"] = philly_bridges["Deck_Width"] * philly_bridges["Structure_Length"]
philly_bridges
# Out:
#         Bridge_ID   Latitude  Longitude  Year_Built Bridge_Condition  \
# 452996     452997  40.103450 -74.961092        1990                G
# 466573     466574  40.017092 -75.211428        1928                F
# 466579     466580  39.963467 -75.186778        1964                P
# 466580     466581  39.963861 -75.185025        1964                P
# 466616     466617  40.035356 -75.208878        1957                F
# ...           ...        ...        ...         ...              ...
# 471579     471580  39.958900 -75.170372        2017                G
# 471995     471996  39.959400 -75.173906        2018                G
# 471997     471998  39.959500 -75.175500        2018                G
# 472286     472287  39.960194 -75.159694        1892                P
# 472287     472288  40.024667 -75.223028        1998                G
#
#         Average_Daily_Traffic  Deck_Width  Structure_Length     SqFt
# 452996                   9729        13.0              18.3   237.90
# 466573                  14596        19.2              32.9   631.68
# 466579                  27042        16.1             167.0  2688.70
# 466580                  27042        16.2              27.1   439.02
# 466616                  28301        20.7             115.2  2384.64
# ...                       ...         ...               ...      ...
# 471579                   8800        19.8              29.9   592.02
# 471995                  13020        20.4              39.0   795.60
# 471997                  12400        25.5              32.9   838.95
# 472286                    150         4.8              17.1    82.08
# 472287                     10         8.4              13.1   110.04
#
# [158 rows x 9 columns]

# %%
# Add column for cost to repair by multipling the SqFt by the cost to repair figures calculated by the US DOT FHA

philly_bridges.loc[:,"Repair_Cost_Est"] = philly_bridges["SqFt"] * 213.52 
philly_bridges
# Out:
#         Bridge_ID   Latitude  Longitude  Year_Built Bridge_Condition  \
# 452996     452997  40.103450 -74.961092        1990                G
# 466573     466574  40.017092 -75.211428        1928                F
# 466579     466580  39.963467 -75.186778        1964                P
# 466580     466581  39.963861 -75.185025        1964                P
# 466616     466617  40.035356 -75.208878        1957                F
# ...           ...        ...        ...         ...              ...
# 471579     471580  39.958900 -75.170372        2017                G
# 471995     471996  39.959400 -75.173906        2018                G
# 471997     471998  39.959500 -75.175500        2018                G
# 472286     472287  39.960194 -75.159694        1892                P
# 472287     472288  40.024667 -75.223028        1998                G
#
#         Average_Daily_Traffic  Deck_Width  Structure_Length     SqFt  \
# 452996                   9729        13.0              18.3   237.90
# 466573                  14596        19.2              32.9   631.68
# 466579                  27042        16.1             167.0  2688.70
# 466580                  27042        16.2              27.1   439.02
# 466616                  28301        20.7             115.2  2384.64
# ...                       ...         ...               ...      ...
# 471579                   8800        19.8              29.9   592.02
# 471995                  13020        20.4              39.0   795.60
# 471997                  12400        25.5              32.9   838.95
# 472286                    150         4.8              17.1    82.08
# 472287                     10         8.4              13.1   110.04
#
#         Repair_Cost_Est
# 452996       50796.4080
# 466573      134876.3136
# 466579      574091.2240
# 466580       93739.5504
# 466616      509168.3328
# ...                 ...
# 471579      126408.1104
# 471995      169876.5120
# 471997      179132.6040
# 472286       17525.7216
# 472287       23495.7408
#
# [158 rows x 10 columns]

# %%
# Add column for cost to replace by multipling the SqFt by the cost to replace figures calculated by the US DOT FHA

philly_bridges.loc[:,"Replacement_Cost_Est"] = philly_bridges["SqFt"] * 314
philly_bridges
# Out:
#         Bridge_ID   Latitude  Longitude  Year_Built Bridge_Condition  \
# 452996     452997  40.103450 -74.961092        1990                G
# 466573     466574  40.017092 -75.211428        1928                F
# 466579     466580  39.963467 -75.186778        1964                P
# 466580     466581  39.963861 -75.185025        1964                P
# 466616     466617  40.035356 -75.208878        1957                F
# ...           ...        ...        ...         ...              ...
# 471579     471580  39.958900 -75.170372        2017                G
# 471995     471996  39.959400 -75.173906        2018                G
# 471997     471998  39.959500 -75.175500        2018                G
# 472286     472287  39.960194 -75.159694        1892                P
# 472287     472288  40.024667 -75.223028        1998                G
#
#         Average_Daily_Traffic  Deck_Width  Structure_Length     SqFt  \
# 452996                   9729        13.0              18.3   237.90
# 466573                  14596        19.2              32.9   631.68
# 466579                  27042        16.1             167.0  2688.70
# 466580                  27042        16.2              27.1   439.02
# 466616                  28301        20.7             115.2  2384.64
# ...                       ...         ...               ...      ...
# 471579                   8800        19.8              29.9   592.02
# 471995                  13020        20.4              39.0   795.60
# 471997                  12400        25.5              32.9   838.95
# 472286                    150         4.8              17.1    82.08
# 472287                     10         8.4              13.1   110.04
#
#         Repair_Cost_Est  Replacement_Cost_Est
# 452996       50796.4080              74700.60
# 466573      134876.3136             198347.52
# 466579      574091.2240             844251.80
# 466580       93739.5504             137852.28
# 466616      509168.3328             748776.96
# ...                 ...                   ...
# 471579      126408.1104             185894.28
# 471995      169876.5120             249818.40
# 471997      179132.6040             263430.30
# 472286       17525.7216              25773.12
# 472287       23495.7408              34552.56
#
# [158 rows x 11 columns]

# %%
# Reformat the new cost estimate columns as currancy

def format_currency(amount):
    return '${:,.2f}'.format(amount)
philly_bridges['Repair_Cost_Est'] = philly_bridges['Repair_Cost_Est'].apply(format_currency)
philly_bridges['Replacement_Cost_Est'] = philly_bridges['Replacement_Cost_Est'].apply(format_currency)
philly_bridges
# Out:
#         Bridge_ID   Latitude  Longitude  Year_Built Bridge_Condition  \
# 452996     452997  40.103450 -74.961092        1990                G
# 466573     466574  40.017092 -75.211428        1928                F
# 466579     466580  39.963467 -75.186778        1964                P
# 466580     466581  39.963861 -75.185025        1964                P
# 466616     466617  40.035356 -75.208878        1957                F
# ...           ...        ...        ...         ...              ...
# 471579     471580  39.958900 -75.170372        2017                G
# 471995     471996  39.959400 -75.173906        2018                G
# 471997     471998  39.959500 -75.175500        2018                G
# 472286     472287  39.960194 -75.159694        1892                P
# 472287     472288  40.024667 -75.223028        1998                G
#
#         Average_Daily_Traffic  Deck_Width  Structure_Length     SqFt  \
# 452996                   9729        13.0              18.3   237.90
# 466573                  14596        19.2              32.9   631.68
# 466579                  27042        16.1             167.0  2688.70
# 466580                  27042        16.2              27.1   439.02
# 466616                  28301        20.7             115.2  2384.64
# ...                       ...         ...               ...      ...
# 471579                   8800        19.8              29.9   592.02
# 471995                  13020        20.4              39.0   795.60
# 471997                  12400        25.5              32.9   838.95
# 472286                    150         4.8              17.1    82.08
# 472287                     10         8.4              13.1   110.04
#
#        Repair_Cost_Est Replacement_Cost_Est
# 452996      $50,796.41           $74,700.60
# 466573     $134,876.31          $198,347.52
# 466579     $574,091.22          $844,251.80
# 466580      $93,739.55          $137,852.28
# 466616     $509,168.33          $748,776.96
# ...                ...                  ...
# 471579     $126,408.11          $185,894.28
# 471995     $169,876.51          $249,818.40
# 471997     $179,132.60          $263,430.30
# 472286      $17,525.72           $25,773.12
# 472287      $23,495.74           $34,552.56
#
# [158 rows x 11 columns]

# %%
# Replace letter grades with full words to be more user freindly

philly_bridges["Bridge_Condition"] = philly_bridges["Bridge_Condition"].replace({'P': 'Poor', 'F': 'Fair', 'G': 'Good'})

philly_bridges
# Out:
#         Bridge_ID   Latitude  Longitude  Year_Built Bridge_Condition  \
# 452996     452997  40.103450 -74.961092        1990             Good
# 466573     466574  40.017092 -75.211428        1928             Fair
# 466579     466580  39.963467 -75.186778        1964             Poor
# 466580     466581  39.963861 -75.185025        1964             Poor
# 466616     466617  40.035356 -75.208878        1957             Fair
# ...           ...        ...        ...         ...              ...
# 471579     471580  39.958900 -75.170372        2017             Good
# 471995     471996  39.959400 -75.173906        2018             Good
# 471997     471998  39.959500 -75.175500        2018             Good
# 472286     472287  39.960194 -75.159694        1892             Poor
# 472287     472288  40.024667 -75.223028        1998             Good
#
#         Average_Daily_Traffic  Deck_Width  Structure_Length     SqFt  \
# 452996                   9729        13.0              18.3   237.90
# 466573                  14596        19.2              32.9   631.68
# 466579                  27042        16.1             167.0  2688.70
# 466580                  27042        16.2              27.1   439.02
# 466616                  28301        20.7             115.2  2384.64
# ...                       ...         ...               ...      ...
# 471579                   8800        19.8              29.9   592.02
# 471995                  13020        20.4              39.0   795.60
# 471997                  12400        25.5              32.9   838.95
# 472286                    150         4.8              17.1    82.08
# 472287                     10         8.4              13.1   110.04
#
#        Repair_Cost_Est Replacement_Cost_Est
# 452996      $50,796.41           $74,700.60
# 466573     $134,876.31          $198,347.52
# 466579     $574,091.22          $844,251.80
# 466580      $93,739.55          $137,852.28
# 466616     $509,168.33          $748,776.96
# ...                ...                  ...
# 471579     $126,408.11          $185,894.28
# 471995     $169,876.51          $249,818.40
# 471997     $179,132.60          $263,430.30
# 472286      $17,525.72           $25,773.12
# 472287      $23,495.74           $34,552.56
#
# [158 rows x 11 columns]

# %%
#Reverse geocode the latitude and longitude to provide the actual addresses of the bridges to be more user friendly

geolocator = Nominatim(user_agent="bridge_address")

def reverse_geocode(row):
    location = geolocator.reverse((row["Latitude"], row['Longitude']), exactly_one=True)
    if location:
        return location.address
    else:
        return "N/A"
    
#Add in Address column with reverse geocode data
philly_bridges["Address"] = philly_bridges.apply(reverse_geocode, axis=1)

philly_bridges
# Out:
#         Bridge_ID   Latitude  Longitude  Year_Built Bridge_Condition  \
# 452996     452997  40.103450 -74.961092        1990             Good
# 466573     466574  40.017092 -75.211428        1928             Fair
# 466579     466580  39.963467 -75.186778        1964             Poor
# 466580     466581  39.963861 -75.185025        1964             Poor
# 466616     466617  40.035356 -75.208878        1957             Fair
# ...           ...        ...        ...         ...              ...
# 471579     471580  39.958900 -75.170372        2017             Good
# 471995     471996  39.959400 -75.173906        2018             Good
# 471997     471998  39.959500 -75.175500        2018             Good
# 472286     472287  39.960194 -75.159694        1892             Poor
# 472287     472288  40.024667 -75.223028        1998             Good
#
#         Average_Daily_Traffic  Deck_Width  Structure_Length     SqFt  \
# 452996                   9729        13.0              18.3   237.90
# 466573                  14596        19.2              32.9   631.68
# 466579                  27042        16.1             167.0  2688.70
# 466580                  27042        16.2              27.1   439.02
# 466616                  28301        20.7             115.2  2384.64
# ...                       ...         ...               ...      ...
# 471579                   8800        19.8              29.9   592.02
# 471995                  13020        20.4              39.0   795.60
# 471997                  12400        25.5              32.9   838.95
# 472286                    150         4.8              17.1    82.08
# 472287                     10         8.4              13.1   110.04
#
#        Repair_Cost_Est Replacement_Cost_Est  \
# 452996      $50,796.41           $74,700.60
# 466573     $134,876.31          $198,347.52
# 466579     $574,091.22          $844,251.80
# 466580      $93,739.55          $137,852.28
# 466616     $509,168.33          $748,776.96
# ...                ...                  ...
# 471579     $126,408.11          $185,894.28
# 471995     $169,876.51          $249,818.40
# 471997     $179,132.60          $263,430.30
# 472286      $17,525.72           $25,773.12
# 472287      $23,495.74           $34,552.56
#
#                                                   Address
# 452996  Dunksferry Road, Mechanicsville, Bensalem Town...
# 466573  Ridge Avenue, Wissahickon, Philadelphia, Phila...
# 466579  Spring Garden Street, Mantua, Philadelphia, Ph...
# 466580  2917, Spring Garden Street, Mantua, Philadelph...
# 466616  Henry Avenue, Philadelphia, Philadelphia Count...
# ...                                                   ...
# 471579  North 19th Street, Center City, Philadelphia, ...
# 471995  Vine Street Expressway, Center City, Philadelp...
# 471997  North 22nd Street, Center City, Philadelphia, ...
# 472286  Noble Street, Chinatown, Center City, Philadel...
# 472287  Cotton Street, Manayunk, Philadelphia, Philade...
#
# [158 rows x 12 columns]

# %%
words_to_delete = [', Philadelphia', ', Philadelphia County', ', Bucks', ' County', 
                   ', Bensalem Township', ', Pennsylvania', ', United States']

def remove_words(text, words):
    pattern = r'\b(?:{})\b'.format('|'.join(words))
    return re.sub(pattern, '', text)

philly_bridges['Address'] = philly_bridges['Address'].apply(lambda x: remove_words(x, words_to_delete))

philly_bridges
# Out:
#         Bridge_ID   Latitude  Longitude  Year_Built Bridge_Condition  \
# 452996     452997  40.103450 -74.961092        1990             Good
# 466573     466574  40.017092 -75.211428        1928             Fair
# 466579     466580  39.963467 -75.186778        1964             Poor
# 466580     466581  39.963861 -75.185025        1964             Poor
# 466616     466617  40.035356 -75.208878        1957             Fair
# ...           ...        ...        ...         ...              ...
# 471579     471580  39.958900 -75.170372        2017             Good
# 471995     471996  39.959400 -75.173906        2018             Good
# 471997     471998  39.959500 -75.175500        2018             Good
# 472286     472287  39.960194 -75.159694        1892             Poor
# 472287     472288  40.024667 -75.223028        1998             Good
#
#         Average_Daily_Traffic  Deck_Width  Structure_Length     SqFt  \
# 452996                   9729        13.0              18.3   237.90
# 466573                  14596        19.2              32.9   631.68
# 466579                  27042        16.1             167.0  2688.70
# 466580                  27042        16.2              27.1   439.02
# 466616                  28301        20.7             115.2  2384.64
# ...                       ...         ...               ...      ...
# 471579                   8800        19.8              29.9   592.02
# 471995                  13020        20.4              39.0   795.60
# 471997                  12400        25.5              32.9   838.95
# 472286                    150         4.8              17.1    82.08
# 472287                     10         8.4              13.1   110.04
#
#        Repair_Cost_Est Replacement_Cost_Est  \
# 452996      $50,796.41           $74,700.60
# 466573     $134,876.31          $198,347.52
# 466579     $574,091.22          $844,251.80
# 466580      $93,739.55          $137,852.28
# 466616     $509,168.33          $748,776.96
# ...                ...                  ...
# 471579     $126,408.11          $185,894.28
# 471995     $169,876.51          $249,818.40
# 471997     $179,132.60          $263,430.30
# 472286      $17,525.72           $25,773.12
# 472287      $23,495.74           $34,552.56
#
#                                             Address
# 452996       Dunksferry Road, Mechanicsville, 19020
# 466573             Ridge Avenue, Wissahickon, 19127
# 466579          Spring Garden Street, Mantua, 19104
# 466580    2917, Spring Garden Street, Mantua, 19104
# 466616                          Henry Avenue, 19127
# ...                                             ...
# 471579        North 19th Street, Center City, 19132
# 471995   Vine Street Expressway, Center City, 19103
# 471997        North 22nd Street, Center City, 19103
# 472286  Noble Street, Chinatown, Center City, 19123
# 472287               Cotton Street, Manayunk, 19127
#
# [158 rows x 12 columns]

# %%
philly_bridges.to_csv("cleaned_bridge_data.csv", index=False)
